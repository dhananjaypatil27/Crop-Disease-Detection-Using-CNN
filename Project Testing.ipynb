# %% [markdown]
# <a href="https://colab.research.google.com/github/dhananjaypatil27/Crop-Disease-Detection-Using-CNN/blob/main/Project%20Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

path = "/content/drive/MyDrive/PlantVillage_binary_mobilenet.keras"

if os.path.exists(path):
    print("Model found in Drive")
else:
    print(" Model NOT found in Drive")
# Out:
# Model found in Drive

# %%
from tensorflow.keras.models import load_model

model_path = "/content/drive/MyDrive/PlantVillage_binary_mobilenet.keras"
model = load_model(model_path)

print("Model Loaded Successfully")
# Out:
# Model Loaded Successfully

# %%
print(model.input_shape)
# Out:
# (None, 128, 128, 3)

# %%
dataset_path = "/content/drive/MyDrive/PlantVillage"

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# Load model
model = load_model("/content/drive/MyDrive/PlantVillage_binary_mobilenet.keras")

# Dataset path
dataset_path = "/content/drive/MyDrive/PlantVillage"

# Get class names in sorted order
class_names = sorted([
    folder for folder in os.listdir(dataset_path)
    if os.path.isdir(os.path.join(dataset_path, folder))
])

# Pick random image
random_class = random.choice(class_names)
class_path = os.path.join(dataset_path, random_class)
random_image = random.choice(os.listdir(class_path))
image_path = os.path.join(class_path, random_image)

# Load image (model input size = 128x128)
img = image.load_img(image_path, target_size=(128,128))
img_array = image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predict class
prediction = model.predict(img_array)
predicted_index = np.argmax(prediction)
predicted_class = class_names[predicted_index]

# Convert to Healthy / Disease
if "healthy" in predicted_class.lower():
    final_prediction = "Healthy"
else:
    final_prediction = "Disease"

# Show result
plt.imshow(img)
plt.title(f"Actual: {random_class}\nPredicted: {final_prediction} ")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_479/2441799868.py in <cell line: 0>()
#       7
#       8 # Load model
# ----> 9 model = load_model("/content/drive/MyDrive/PlantVillage_binary_mobilenet.keras")
#      10
#      11 # Dataset path
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     201         )
#     202     elif str(filepath).endswith(".keras"):
# --> 203         raise ValueError(
#     204             f"File not found: filepath={filepath}. "
#     205             "Please ensure the file is an accessible `.keras` "
#
# ValueError: File not found: filepath=/content/drive/MyDrive/PlantVillage_binary_mobilenet.keras. Please ensure the file is an accessible `.keras` zip file.
